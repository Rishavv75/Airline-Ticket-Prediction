# %%
import pandas as pd
import numpy as np

df = pd.read_excel("../../data/raw/flights.xlsx")

df.head()
df.shape
df.columns.tolist()
df.info()
df.isnull().sum()
df.duplicated().sum()
df.head()
print("Airlines:")
print(df["Airline"].value_counts())

print("\nSources:")
print(df["Source"].value_counts())

print("\nDestinations:")
print(df["Destination"].value_counts())

print("\nStops:")
print(df["Total_Stops"].value_counts())

print("\nAdditional Info:")
print(df["Additional_Info"].value_counts())

df["Price"].describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  str
#  1   Date_of_Journey  10683 non-null  str
#  2   Source           10683 non-null  str
#  3   Destination      10683 non-null  str
#  4   Route            10682 non-null  str
#  5   Dep_Time         10683 non-null  str
#  6   Arrival_Time     10683 non-null  str
#  7   Duration         10683 non-null  str
#  8   Total_Stops      10682 non-null  str
#  9   Additional_Info  10683 non-null  str
#  10  Price            10683 non-null  int64
# dtypes: int64(1), str(10)
# memory usage: 918.2 KB
# Airlines:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# ...

# %%
df[["Route", "Total_Stops"]].head(20)
# Out:
#                     Route Total_Stops
# 0               BLR → DEL    non-stop
# 1   CCU → IXR → BBI → BLR     2 stops
# 2   DEL → LKO → BOM → COK     2 stops
# 3         CCU → NAG → BLR      1 stop
# 4         BLR → NAG → DEL      1 stop
# 5               CCU → BLR    non-stop
# 6         BLR → BOM → DEL      1 stop
# 7         BLR → BOM → DEL      1 stop
# 8         BLR → BOM → DEL      1 stop
# 9         DEL → BOM → COK      1 stop
# 10        DEL → BLR → COK      1 stop
# 11              CCU → BLR    non-stop
# 12              MAA → CCU    non-stop
# 13        CCU → BOM → BLR      1 stop
# 14              CCU → BLR    non-stop
# 15  DEL → AMD → BOM → COK     2 stops
# 16        DEL → PNQ → COK      1 stop
# 17        DEL → BOM → COK      1 stop
# 18  DEL → CCU → BOM → COK     2 stops
# 19        DEL → BOM → COK      1 stop

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(220)

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df["Additional_Info"].value_counts()
# Out:
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
df["Price"].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
df[["Route", "Total_Stops"]].head(20)
# Out:
#                     Route Total_Stops
# 0               BLR → DEL    non-stop
# 1   CCU → IXR → BBI → BLR     2 stops
# 2   DEL → LKO → BOM → COK     2 stops
# 3         CCU → NAG → BLR      1 stop
# 4         BLR → NAG → DEL      1 stop
# 5               CCU → BLR    non-stop
# 6         BLR → BOM → DEL      1 stop
# 7         BLR → BOM → DEL      1 stop
# 8         BLR → BOM → DEL      1 stop
# 9         DEL → BOM → COK      1 stop
# 10        DEL → BLR → COK      1 stop
# 11              CCU → BLR    non-stop
# 12              MAA → CCU    non-stop
# 13        CCU → BOM → BLR      1 stop
# 14              CCU → BLR    non-stop
# 15  DEL → AMD → BOM → COK     2 stops
# 16        DEL → PNQ → COK      1 stop
# 17        DEL → BOM → COK      1 stop
# 18  DEL → CCU → BOM → COK     2 stops
# 19        DEL → BOM → COK      1 stop

# %%
df[df["Route"].isna() | df["Additional_Info"].isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df[df.duplicated(keep=False)].sort_values(
    by=["Airline", "Source", "Destination"]
).head(20)
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 5222  Air India      12/03/2019  Banglore   New Delhi  BLR → BOM → NAG → DEL
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9942  Air India      12/03/2019  Banglore   New Delhi  BLR → BOM → NAG → DEL
# 137   Air India      27/06/2019     Delhi      Cochin  DEL → GOI → BOM → COK
# 251   Air India       1/06/2019     Delhi      Cochin  DEL → AMD → BOM → COK
# 406   Air India      21/05/2019     Delhi      Cochin  DEL → BHO → BOM → COK
# 410   Air India      18/05/2019     Delhi      Cochin  DEL → HYD → BOM → COK
# 455   Air India      18/05/2019     Delhi      Cochin  DEL → GOI → BOM → COK
# ...

# %%
df[df["Route"].isna() | df["Additional_Info"].isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df[df.duplicated(keep=False)].sort_values(
    by=["Airline", "Source", "Destination"]
).head(20)
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 5222  Air India      12/03/2019  Banglore   New Delhi  BLR → BOM → NAG → DEL
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9942  Air India      12/03/2019  Banglore   New Delhi  BLR → BOM → NAG → DEL
# 137   Air India      27/06/2019     Delhi      Cochin  DEL → GOI → BOM → COK
# 251   Air India       1/06/2019     Delhi      Cochin  DEL → AMD → BOM → COK
# 406   Air India      21/05/2019     Delhi      Cochin  DEL → BHO → BOM → COK
# 410   Air India      18/05/2019     Delhi      Cochin  DEL → HYD → BOM → COK
# 455   Air India      18/05/2019     Delhi      Cochin  DEL → GOI → BOM → COK
# ...

# %%
df["Date_of_Journey"].min(), df["Date_of_Journey"].max()
# Out:
# ('01/03/2019', '9/06/2019')

# %%
df.nlargest(20, "Price")[
    ["Airline", "Source", "Destination", "Route", "Total_Stops", "Price"]
]
# Out:
#                     Airline    Source Destination                  Route  \
# 2924   Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL
# 5372   Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL
# 10364  Jet Airways Business  Banglore   New Delhi        BLR → MAA → DEL
# 1478            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 2618            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5439            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9715   Jet Airways Business     Delhi      Cochin  DEL → ATQ → BOM → COK
# 657    Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL
# 7351   Jet Airways Business     Delhi      Cochin  DEL → ATQ → BOM → COK
# 396       Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 2099            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5719            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# ...

# %%
df[df["Total_Stops"].isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480
